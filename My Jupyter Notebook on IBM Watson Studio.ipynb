# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# #### Gladymar Romero

# %% [markdown]
# Data Analyst

# %% [markdown]
# *I am interested in data science because I would like to help victims of domestic violence. This will help me to get more skills to identify patterns and help to create safe paths for victims and survivors.*

# %% [markdown]
# ### The following code tests 50+64

# %%
50+64
# Out:
# 114

# %% [markdown]
#   * Yellow
#   * Blue
#   * Red
#   * Yellow
#   * Blue
#   * Red

# %% [markdown]
# 1. One
# 2. two
# 3. three
# 4. four
# 5. five

# %% [markdown]
# [Popular search engine](https://www.google.com)

# %% [markdown]
# [Click Here]: http://www.instagram.com

# %% [markdown]
# Today is `January 28th, 2023`
